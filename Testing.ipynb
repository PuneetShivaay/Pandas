# %%
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-0aa0b027fcb6> in <module>
# ----> 1 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
import pandas as pd

# %%
excel_file = 'for testing.xls'

# %%
df = pd.read_excel (r'C:\Users\Puneet Kumar\Desktop\testing.xlsx')

# %%
df
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
df.tail()
# Out:
#     Column1                                            Column2  Column3  \
# 45    21186  cbse $ 4th cbse $ environmental studies $ life...  lm26954
# 46    22575  cbse $ 4th cbse $ environmental studies $ life...  lm25565
# 47    22651  cbse $ 4th cbse $ environmental studies $ life...  lm25489
# 48   144076  cbse $ 4th cbse $ environmental studies $ life...  lm85063
# 49   144090  cbse $ 4th cbse $ environmental studies $ life...  lm85036
#
#    Column4     Column5                  Column6         Column7  \
# 45   cbse    4th cbse    environmental studies    life science
# 46   cbse    4th cbse    environmental studies    life science
# 47   cbse    4th cbse    environmental studies    life science
# 48   cbse    4th cbse    environmental studies    life science
# 49   cbse    4th cbse    environmental studies    life science
#
#            Column8                    Column9
# 45   a busy month                 bird's nest
# 46   a busy month                     animals
# ...

# %%
df.describe()
# Out:
#              Column1
# count      50.000000
# mean   108185.780000
# std     52043.131821
# min     21172.000000
# 25%     57204.000000
# 50%    129094.500000
# 75%    144361.500000
# max    177321.000000

# %%
require_cols = [3,4,5,6, 7] 

required_df = pd.read_excel(r'C:\Users\Puneet Kumar\Desktop\testing.xlsx', usecols = require_cols) 
print(required_df)
# Out:
#                      Column4                        Column5  \
# 0           10th foundation                      10th ntse
# 1           10th foundation                      10th ntse
# 2           10th foundation                      10th ntse
# 3           10th foundation                      10th ntse
# 4           10th foundation                      10th ntse
# 5           10th foundation                      10th ntse
# 6           10th foundation                      10th ntse
# 7                dummy goal             foundation 10 ntse
# 8                dummy goal             foundation 10 ntse
# 9                dummy goal             foundation 10 ntse
# 10               dummy goal             foundation 10 ntse
# 11               dummy goal             foundation 10 ntse
# 12               dummy goal             foundation 10 ntse
# 13              lectureship                ugc net paper 2
# 14              lectureship                ugc net paper 2
# ...

# %%
import sys
import pprint
pprint.pprint(sys.path)
# Out:
# ['C:\\Users\\Puneet Kumar\\Desktop\\Untitled Folder',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\python38.zip',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\DLLs',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib',
#  'C:\\Users\\Puneet Kumar\\anaconda3',
#  '',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib\\site-packages',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib\\site-packages\\win32',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\Users\\Puneet Kumar\\anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\Puneet Kumar\\.ipython']

# %%
pwd
# Out:
# 'C:\\Users\\Puneet Kumar\\Desktop\\Untitled Folder'

# %%
df.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6',
#        'Column7', 'Column8', 'Column9'],
#       dtype='object')

# %%
df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])

# %%
print( df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8']).groups)
# Out:
# {('10th foundation ', ' 10th ntse ', ' mathematics ', ' algebra ', ' "linear equations in one variable '): [0, 1, 2, 3, 4, 5, 6], ('andhra pradesh board ', ' 6th andhra pradesh board ', ' mathematics ', ' geometry ', ' 2d - 3d shapes '): [17, 18, 19, 20, 21, 22], ('cbse ', ' 3rd cbse ', ' environmental studies ', ' social science ', ' a beautiful cloth '): [36, 37, 38, 39, 40, 41], ('cbse ', ' 4th cbse ', ' environmental studies ', ' life science ', ' a busy month '): [44, 45, 46, 47, 48, 49], ('dummy goal ', ' foundation 10 ntse ', ' scholastic aptitude test ', ' history ', ' "the rise of nationalism in europe " '): [7, 8, 9, 10, 11, 12], ('engineering ', ' jee advanced ', ' mathematics ', ' vector algebra ', ' 3d geometry '): [23, 24, 25, 26, 27, 28, 29, 30, 31], ('jammu and kashmir board ', ' 3rd jammu and kashmir board ', ' environmental studies ', ' social science ', ' a beautiful cloth '): [42, 43], ('karnataka board ', ' 5th karnataka state board ', ' mathematics ', ' arithmet
# ...

# %%
a = df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])

# %%
print(a['Column8'])

# %%
a['Column8'].apply(list)
# Out:
# Column4                   Column5                        Column6                             Column7            Column8
# 10th foundation            10th ntse                      mathematics                         algebra            "linear equations in one variable                        [ "linear equations in one variable ,  "linear...
# andhra pradesh board       6th andhra pradesh board       mathematics                         geometry           2d - 3d shapes                                           [ 2d - 3d shapes ,  2d - 3d shapes ,  2d - 3d ...
# cbse                       3rd cbse                       environmental studies               social science     a beautiful cloth                                        [ a beautiful cloth ,  a beautiful cloth ,  a ...
# ...

# %%
for names, grp in a['Column9']:
    print(names)
    print(grp)
# Out:
# ('10th foundation ', ' 10th ntse ', ' mathematics ', ' algebra ', ' "linear equations in one variable ')
# 0               equations reducible to the linear form
# 1                   reducing equations to simpler form
# 2                               some more applications
# 3     solving equations having the variable on both...
# 4                                    some applications
# 5     solving equations which have linear expressio...
# 6        introduction linear equations in one variable
# Name: Column9, dtype: object
# ('andhra pradesh board ', ' 6th andhra pradesh board ', ' mathematics ', ' geometry ', ' 2d - 3d shapes ')
# 17        understanding of 3d shapes
# 18                          symmetry
# 19            introduction of circle
# 20     introduction of quadrilateral
# 21                          polygons
# 22          introduction of triangle
# Name: Column9, dtype: object
# ...

# %%
for ii, (names, grp) in enumerate(a['Column9']) :
        print(names)
        print(ii)


        print(grp)
#         print(grp.index)
# Out:
# ('10th foundation ', ' 10th ntse ', ' mathematics ', ' algebra ', ' "linear equations in one variable ')
# 0
# 0               equations reducible to the linear form
# 1                   reducing equations to simpler form
# 2                               some more applications
# 3     solving equations having the variable on both...
# 4                                    some applications
# 5     solving equations which have linear expressio...
# 6        introduction linear equations in one variable
# Name: Column9, dtype: object
# ('andhra pradesh board ', ' 6th andhra pradesh board ', ' mathematics ', ' geometry ', ' 2d - 3d shapes ')
# 1
# 17        understanding of 3d shapes
# 18                          symmetry
# 19            introduction of circle
# 20     introduction of quadrilateral
# 21                          polygons
# 22          introduction of triangle
# Name: Column9, dtype: object
# ...

# %%
df
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
[(idx,key)  for key,value in df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])['Column1'].apply(list).reset_index()['Column1'].to_dict().items() for idx in value ]
# Out:
# [(51415, 0),
#  (51416, 0),
#  (51417, 0),
#  (51418, 0),
#  (51419, 0),
#  (51420, 0),
#  (51421, 0),
#  (135962, 1),
#  (135963, 1),
#  (135964, 1),
#  (135965, 1),
#  (135966, 1),
#  (135967, 1),
#  (26442, 2),
#  (27945, 2),
#  (144452, 2),
#  (144607, 2),
#  (148933, 2),
#  (149088, 2),
#  (21172, 3),
#  (21186, 3),
#  (22575, 3),
#  (22651, 3),
#  (144076, 3),
#  (144090, 3),
#  (74553, 4),
#  (74554, 4),
#  (74555, 4),
#  (74556, 4),
#  (74557, 4),
#  (74558, 4),
#  (177313, 5),
#  (177314, 5),
#  (177315, 5),
#  (177316, 5),
#  (177317, 5),
#  (177318, 5),
#  (177319, 5),
#  (177320, 5),
#  (177321, 5),
#  (138388, 6),
#  (138389, 6),
#  (129093, 7),
#  (129094, 7),
#  (129095, 7),
#  (129096, 7),
#  (95589, 8),
#  (95588, 9),
#  (93516, 10),
#  (95325, 11)]

# %%
pd.DataFrame([(idx,key)  for key,value in df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])['Column1'].apply(list).reset_index()['Column1'].to_dict().items() for idx in value ]).set_index([0])
# Out:
#          1
# 0
# 51415    0
# 51416    0
# 51417    0
# 51418    0
# 51419    0
# 51420    0
# 51421    0
# 135962   1
# 135963   1
# 135964   1
# 135965   1
# 135966   1
# 135967   1
# 26442    2
# 27945    2
# 144452   2
# 144607   2
# 148933   2
# 149088   2
# 21172    3
# 21186    3
# 22575    3
# 22651    3
# 144076   3
# 144090   3
# 74553    4
# 74554    4
# 74555    4
# 74556    4
# 74557    4
# 74558    4
# 177313   5
# 177314   5
# 177315   5
# 177316   5
# 177317   5
# 177318   5
# 177319   5
# 177320   5
# 177321   5
# 138388   6
# 138389   6
# 129093   7
# 129094   7
# 129095   7
# 129096   7
# 95589    8
# 95588    9
# 93516   10
# 95325   11

# %%
df.join(pd.DataFrame([(idx,key)  for key,value in df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])['Column1'].apply(list).reset_index()['Column1'].to_dict().items() for idx in value ],columns=[0,'Column10']).set_index([0]),on=['Column1'])
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
df
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
a = "ABCDEFGHIJKLMNOPQRSTUVWXYZ0123456789";

# %%
z=dict(enumerate([i+j+k+l for i in a for j in a for k in a for l in a]))

# %%
b = df.join(pd.DataFrame([(idx,key)  for key,value in df.groupby(['Column4', 'Column5', 'Column6',
       'Column7', 'Column8'])['Column1'].apply(list).reset_index()['Column1'].to_dict().items() for idx in value ],columns=[0,'Column10']).set_index([0]),on=['Column1'])

# %%
b['Column10']=b['Column10'].map(z)

# %%
b
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
b.to_excel('long.xlsx')

# %%
pwd
# Out:
# 'C:\\Users\\Puneet Kumar\\Desktop\\Untitled Folder'

# %%
b[['Column4','Column5','Column6','Column7','Column8','Column10']]
# Out:
#                      Column4                        Column5  \
# 0           10th foundation                      10th ntse
# 1           10th foundation                      10th ntse
# 2           10th foundation                      10th ntse
# 3           10th foundation                      10th ntse
# 4           10th foundation                      10th ntse
# 5           10th foundation                      10th ntse
# 6           10th foundation                      10th ntse
# 7                dummy goal             foundation 10 ntse
# 8                dummy goal             foundation 10 ntse
# 9                dummy goal             foundation 10 ntse
# 10               dummy goal             foundation 10 ntse
# 11               dummy goal             foundation 10 ntse
# 12               dummy goal             foundation 10 ntse
# 13              lectureship                ugc net paper 2
# 14              lectureship                ugc net paper 2
# ...

# %%
s=b.drop_duplicates(subset=['Column10'])

# %%
b
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 1     51416  10th foundation $ 10th ntse $ mathematics $ al...  lm193875
# 2     51417  10th foundation $ 10th ntse $ mathematics $ al...  lm193873
# 3     51418  10th foundation $ 10th ntse $ mathematics $ al...  lm193871
# 4     51419  10th foundation $ 10th ntse $ mathematics $ al...  lm193869
# 5     51420  10th foundation $ 10th ntse $ mathematics $ al...  lm193867
# 6     51421  10th foundation $ 10th ntse $ mathematics $ al...  lm193865
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 8     74554  dummy goal $ foundation 10 ntse $ scholastic a...  lm218867
# 9     74555  dummy goal $ foundation 10 ntse $ scholastic a...  lm218866
# 10    74556  dummy goal $ foundation 10 ntse $ scholastic a...  lm218865
# 11    74557  dummy goal $ foundation 10 ntse $ scholastic a...  lm218864
# ...

# %%
s
# Out:
#     Column1                                            Column2   Column3  \
# 0     51415  10th foundation $ 10th ntse $ mathematics $ al...  lm193876
# 7     74553  dummy goal $ foundation 10 ntse $ scholastic a...  lm218868
# 13    95325  lectureship $ ugc net paper 2 $ urdu $ تاریخ ز...  lm522197
# 14    93516  lectureship $ ugc net paper 2 $ chinese $ 现代汉语...  lm541533
# 15    95589  lectureship $ ugc net paper 2 $ arab culture a...  lm402639
# 16    95588  lectureship $ ugc net paper 2 $ arab culture a...  lm402640
# 17   135962  andhra pradesh board $ 6th andhra pradesh boar...  lm483641
# 23   177313  engineering $ jee advanced $ mathematics $ vec...  lm205920
# 32   129093  karnataka board $ 5th karnataka state board $ ...  lm326434
# 36    26442  cbse $ 3rd cbse $ environmental studies $ soci...   lm21698
# 42   138388  jammu and kashmir board $ 3rd jammu and kashmi...  lm421442
# 44    21172  cbse $ 4th cbse $ environmental studies $ life...   lm26968
#
# ...

# %%
s.to_excel('short.xlsx')
