# %%
import numpy as np

# %%
import pandas as pd
import json

# %%
df = pd.read_json (r'C:\Users\Puneet Kumar\Desktop\sample.json')
print(df)
# Out:
#             Product  Price
# 0  Desktop Computer    700
# 1            Tablet    250
# 2            iPhone    800
# 3            Laptop   1200

# %%
import json
import pandas as pd
with open('C:\Users\Puneet Kumar\Desktop\jj.json') as f:
  df = pd.DataFrame([json.loads(l) for l in f.readlines()])
print(df)
# Out:
#   File "<ipython-input-17-95e0009e01b5>", line 3
#     with open('C:\Users\Puneet Kumar\Desktop\jj.json') as f:
#                                                      ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
df = pd.read_json (r'C:\Users\Puneet Kumar\Desktop\jj.json', typ='series')
print(df)
# Out:
# F-A023                                    True
# F-A024                                    True
# F-A025                                    True
# F-A028                                    True
# F-A029                                    True
#                                           ...
# F-MKOF                                    True
# F-MKOG                                    True
# F-MKOH                                    True
# F-MZ2N                                    True
# F-undefinedundefinedundefinedundefined    True
# Length: 142599, dtype: bool

# %%
df.head
# Out:
# <bound method NDFrame.head of F-A023                                    True
# F-A024                                    True
# F-A025                                    True
# F-A028                                    True
# F-A029                                    True
#                                           ...
# F-MKOF                                    True
# F-MKOG                                    True
# F-MKOH                                    True
# F-MZ2N                                    True
# F-undefinedundefinedundefinedundefined    True
# Length: 142599, dtype: bool>

# %%
df.to_excel('DATAFILE.xlsx')

# %%
print(df)
# Out:
# F-A023                                    True
# F-A024                                    True
# F-A025                                    True
# F-A028                                    True
# F-A029                                    True
#                                           ...
# F-MKOF                                    True
# F-MKOG                                    True
# F-MKOH                                    True
# F-MZ2N                                    True
# F-undefinedundefinedundefinedundefined    True
# Length: 142599, dtype: bool

# %%
import pandas as pd

df1=pd.read_excel(r'C:\Users\Puneet Kumar\Desktop\pandas\DATAFILE.xlsx')

# %%
df1
# Out:
#                                              A     B
# 0                                       F-A023  True
# 1                                       F-A024  True
# 2                                       F-A025  True
# 3                                       F-A028  True
# 4                                       F-A029  True
# ...                                        ...   ...
# 142594                                  F-MKOF  True
# 142595                                  F-MKOG  True
# 142596                                  F-MKOH  True
# 142597                                  F-MZ2N  True
# 142598  F-undefinedundefinedundefinedundefined  True
#
# [142599 rows x 2 columns]

# %%
df2
# Out:
#                                                         A       B       C
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
# [244103 rows x 3 columns]

# %%
result = df2.loc[df2['B'].isin(df1['A'])]

# %%
print(result)
# Out:
#                                                         A       B       C
# 20      10th foundation $ 10th foundation $ general en...  F-BSJN  C-AICJ
# 22      10th foundation $ 10th foundation $ general en...  F-BSJZ  C-AICJ
# 24      10th foundation $ 10th foundation $ general en...  F-BSJP  C-AICJ
# 36      10th foundation $ 10th foundation $ general en...  F-BSKF  C-AV18
# 40      10th foundation $ 10th foundation $ general en...  F-BSKT  C-AV18
# ...                                                   ...     ...     ...
# 244039  west bengal board $ 8th west bengal board $ sc...  F-KQLO  C-AOV6
# 244040  west bengal board $ 8th west bengal board $ sc...  F-KQLP  C-AOV6
# 244041  west bengal board $ 8th west bengal board $ sc...  F-KQLN  C-AOV6
# 244042  west bengal board $ 8th west bengal board $ sc...  F-KQLQ  C-AOV6
# 244043  west bengal board $ 8th west bengal board $ sc...  F-KQLR  C-AOV6
#
# [136132 rows x 3 columns]

# %%
import pandas as pd

df2=pd.read_excel(r'C:\Users\Puneet Kumar\Desktop\pandas\FinalFile.xlsx')

# %%
print(df1)
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D
# 0       F-A023
# 1       F-A024
# 2       F-A025
# ...

# %%
df1["exist"] = df1.drop("B", 1).isin(df1["B"]).any(1)

# %%
df1
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023  False
# 1       F-A024  False
# ...

# %%
df1.to_excel('check.xlsx')

# %%
print(df2)
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023   True
# 1       F-A024   True
# ...

# %%
df1["exist"] = df1.drop("B", 1).isin(df1["D"]).any(1)

# %%
df2
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023   True
# 1       F-A024   True
# ...

# %%
df2.head()
# Out:
#                                                    A       B       C       D  \
# 0                                              1 $ 2  F-LJ2C  C-AZWZ  F-A023
# 1                                          1 $ 2 $ 3  F-LJ18  C-AZWQ  F-A024
# 2                                          1 $ 2 $ 4  F-LJ2A  C-AZWS  F-A025
# 3  10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH  F-A028
# 4  10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV  F-A029
#
#    exist
# 0   True
# 1   True
# 2   True
# 3   True
# 4   True

# %%
df2.tail()
# Out:
#                                                         A       B       C  \
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#           D  exist
# 244098  NaN   True
# 244099  NaN   True
# 244100  NaN   True
# 244101  NaN   True
# 244102  NaN   True

# %%
df2.to_excel('short2.xlsx')

# %%
for key in df2:
    df2["exist"] = df2["B"][key].isin(df2["D"][key])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-72-9cca80bf2a6f> in <module>
#       1 for key in df2:
# ----> 2     df2["exist"] = df2["B"][key].isin(df2["D"][key])
#
# d:\data\ok\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     851
#     852         elif key_is_scalar:
# --> 853             return self._get_value(key)
#     854
#     855         if is_hashable(key):
#
# d:\data\ok\lib\site-packages\pandas\core\series.py in _get_value(self, label, takeable)
#     959
#     960         # Similar to Index.get_value, but we do not fall back to positional
# --> 961         loc = self.index.get_loc(label)
#     962         return self.index._get_values_for_loc(self, loc, label)
#     963
#
# d:\data\ok\lib\site-packages\pandas\core\indexes\range.py in get_loc(self, key, method, tolerance)
#     352                 except ValueError as err:
# ...

# %%
df2
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023  False
# 1       F-A024  False
# ...

# %%
df2.col(B).isin(df2.col(D))

# %%
df2["exist"] = df2.B.isin(df2.D)

# %%
df1["exist"] = df1.drop("B", 1).isin(df1["D"]).any(1)

# %%
print(df2)
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023  False
# 1       F-A024  False
# ...

# %%
for i in range(244103):
    df2["exist"] = df2.drop("B"[i], 1).isin(df2["D"[i]]).any(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-85-9565329c565d> in <module>
#       1 for i in range(244103):
# ----> 2     df2["exist"] = df2.drop("B", 1).isin(df2["D"]).any(1)
#       3
#
# d:\data\ok\lib\site-packages\pandas\core\frame.py in isin(self, values)
#    9418             if not values.index.is_unique:
#    9419                 raise ValueError("cannot compute isin with a duplicate axis.")
# -> 9420             return self.eq(values.reindex_like(self), axis="index")
#    9421         elif isinstance(values, DataFrame):
#    9422             if not (values.columns.is_unique and values.index.is_unique):
#
# d:\data\ok\lib\site-packages\pandas\core\ops\__init__.py in f(self, other, axis, level)
#     447         axis = self._get_axis_number(axis) if axis is not None else 1
#     448
# ...

# %%
df2["exist"] = df2.drop("B", [i]).isin(df2["D"]).any(i)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-101-46075d5d6b7b> in <module>
# ----> 1 df2["exist"] = df2.drop("B", [i]).isin(df2["D"]).any(i)
#
# d:\data\ok\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4306                 weight  1.0     0.8
#    4307         """
# -> 4308         return super().drop(
#    4309             labels=labels,
#    4310             axis=axis,
#
# d:\data\ok\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4138             if index is not None or columns is not None:
#    4139                 raise ValueError("Cannot specify both 'labels' and 'index'/'columns'")
# -> 4140             axis_name = self._get_axis_name(axis)
#    4141             axes = {axis_name: labels}
# ...

# %%
df2
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D  exist
# 0       F-A023   True
# 1       F-A024   True
# ...

# %%
df2.to_excel('short5.xlsx')

# %%
df2["exist"] =np.where(df2.D.isin(df2.B), df1.B, 'NO_MATCH')

# %%
df2
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D     exist
# 0       F-A023    F-LJ2C
# 1       F-A024    F-LJ18
# ...

# %%
df2["exist"] =np.where(df2.D.isin(df2.B), df1.B, False)

# %%
df2
# Out:
#                                                         A       B       C  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV
# ...                                                   ...     ...     ...
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA
#
#              D   exist
# 0       F-A023  F-LJ2C
# 1       F-A024  F-LJ18
# ...

# %%
df2.to_excel('out.xlsx')
