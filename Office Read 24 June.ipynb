# %%
#import pandas as pd

# %%
#df1=pd.read_excel(r"C:\Users\Puneet Kumar\Desktop\FinalFile.xlsx")

# %%
#df1

# %%
#!pip3 install openpyxl

# %%
#!pip freeze

# %%
#!pip install --upgrade pip

# %%
#df1

# %%
#df1['diff'] = df.groupby('temp')['salary']

# %%
###
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\Puneet Kumar\Desktop\FinalFile.xlsx")

# %%
# Out:
#                                                      Name       F       C   S  \
# 0                                                   1 $ 2  F-LJ2C  C-AZWZ NaN
# 1                                               1 $ 2 $ 3  F-LJ18  C-AZWQ NaN
# 2                                               1 $ 2 $ 4  F-LJ2A  C-AZWS NaN
# 3       10th foundation $ 10th foundation $ chemistry ...  F-BTJ5  C-ADOH NaN
# 4       10th foundation $ 10th foundation $ chemistry ...  F-BTJ3  C-AAJV NaN
# ...                                                   ...     ...     ...  ..
# 244098  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPQ  C-AXLA NaN
# 244099  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPP  C-AXLA NaN
# 244100  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPR  C-AXLA NaN
# 244101  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPT  C-AXLA NaN
# 244102  अभियांत्रिकी $ जे.ई.ई. मेन $ भौतिक विज्ञान $ स...  F-JKPS  C-AXLA NaN
#
#         Unnamed: 4  Unnamed: 5
# ...

# %%
dfg =

# %%
df2=pd.read_excel(r"C:\Users\Puneet Kumar\Desktop\code6.xlsx")
df2
# Out:
#      Chapter \nNo.                     Chapter   \
# 0              1.0         Knowing Your Numbers
# 1              NaN                          NaN
# 2              2.0                Whole Numbers
# 3              NaN                          NaN
# 4              NaN                          NaN
# ..             ...                          ...
# 208            NaN                          NaN
# 209            9.0   useful plants and animals
# 210            NaN                          NaN
# 211            NaN                          NaN
# 212           10.0                     habitat
#
#           Alternative Chapter Name   Codes  Quantity   Y
# 0             knowing our numbers   C-AJ9G     14220 NaN
# 1                         numbers   C-ANLA      7042 NaN
# 2                  पूर्ण संख्याएँ   C-AXN9      1015 NaN
# 3                        पूर्णांक   C-AXOB       329 NaN
# 4                         पूर्णाक   C-AXOE      2571 NaN
# ...

# %%
## aa= df[df["C"] =='C-AXLA']

# %%
for i in range (28315,29400):
    if df["C"][i]==df["C"][i+1]:
        #print(df["C"][i])
        for j in range (0,212):
            if df["C"][i]==df2["Codes"][j]:
                df2['V'] = (df["Name"][i]+df["F"][i])
                print("matched")
            else:
                pass
    else:                        
        print("vsd")
# Out:
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd
# vsd

# %%
df2
# Out:
#      Chapter \nNo.                     Chapter   \
# 0              1.0         Knowing Your Numbers
# 1              NaN                          NaN
# 2              2.0                Whole Numbers
# 3              NaN                          NaN
# 4              NaN                          NaN
# ..             ...                          ...
# 208            NaN                          NaN
# 209            9.0   useful plants and animals
# 210            NaN                          NaN
# 211            NaN                          NaN
# 212           10.0                     habitat
#
#           Alternative Chapter Name   Codes  Quantity   Y  \
# 0             knowing our numbers   C-AJ9G     14220 NaN
# 1                         numbers   C-ANLA      7042 NaN
# 2                  पूर्ण संख्याएँ   C-AXN9      1015 NaN
# 3                        पूर्णांक   C-AXOB       329 NaN
# 4                         पूर्णाक   C-AXOE      2571 NaN
# ...

# %%
#df2.to_excel('aaa.xlsx')
df2.to_excel(r"C:\Users\Puneet Kumar\Desktop\okk.xlsx", sheet_name='sheet', index = False)

# %%
#bb = df[df["C"][244100]]==df[df["C"][244102]]

# %%
#for i in range (0,20):
    #if df[df["C"][i]]==df[df["C"][i+1]]:
    #print(df["C"][i])
